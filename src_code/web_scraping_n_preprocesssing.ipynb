# %%
# !pip install wikipedia-api
# Out:
# Requirement already satisfied: wikipedia-api in c:\users\vatsa\anaconda3\lib\site-packages (0.6.0)
# Requirement already satisfied: requests in c:\users\vatsa\anaconda3\lib\site-packages (from wikipedia-api) (2.31.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\vatsa\anaconda3\lib\site-packages (from requests->wikipedia-api) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\vatsa\anaconda3\lib\site-packages (from requests->wikipedia-api) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\vatsa\anaconda3\lib\site-packages (from requests->wikipedia-api) (1.26.16)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\vatsa\anaconda3\lib\site-packages (from requests->wikipedia-api) (2023.7.22)

# %%
import wikipediaapi
import random
import time
import concurrent.futures
import requests
import re
import json
import os

# %%
topic_dict2 = {
    "Health": ["Common diseases", "Global health statistics", "COVID-19", "Cancer", "Heart disease", "Diabetes", "Obesity"],
    "Environment": ["Global warming", "Endangered species", "Climate change", "Rainforests", "Pollution", "Biodiversity", "Natural disasters"],
    "Technology": ["Emerging technologies", "AI advancements", "Artificial intelligence", "Machine learning", "Space exploration", "Cybersecurity threats", "Blockchain technology"],
    "Economy": ["Wall Street Crash of 1929", "Stock market performance", "Job Markets", "2007–2008 financial crisis", "Unemployment rates", "Global trade agreements", "Cryptocurrencies", "Economic recession"],
    "Entertainment": ["Music Industry", "Popular cultural events", "Hollywood movies", "Music festivals", "Video streaming platforms", "Celebrities", "Award shows"],
    "Sports": ["Badminton", "Basketball", "Motorsport", "Football", "Cricket", "Olympic records"],
    "Politics": ["Presidential elections", "Foreign policy", "Democracy vs. Authoritarianism", "Political parties", "Human rights issues"],
    "Education": ["Online learning platforms", "STEM education", "School funding", "Educational reforms", "Digital classrooms"],
    "Travel": ["Tourism hotspots", "Airline industry challenges", "Adventure travel destinations", "Hotel chains", "Travel tips"],
    "Food": ["Food Power", "Famine", "Food Security", "Healthy eating", "Farm-to-table movement", "Fast food industry", "Global food distribution", "Veganism"]
}

topic_dict3 = {
                "Health": [
                    "Common diseases",
                    "Global health statistics",
                    "COVID-19",
                    "Cancer",
                    "Heart disease",
                    "Diabetes",
                    "Obesity",
                    "Mental health disorders",
                    "Vaccination controversies",
                    "Pandemics in history",
                    "Healthcare systems worldwide",
                    "Alternative medicine practices",
                    "Aging population challenges",
                    "Epidemiology",
                    "Nutrition and health",
                    "Antibiotic resistance",
                    "Health disparities",
                    "Genetic disorders",
                    "Public health policies",
                    "Maternal and child health",
                    "Healthcare innovations",
                    "Stress-related illnesses",
                    "Sleep disorders",
                    "Addiction and rehabilitation",
                    "Occupational health and safety",
                    "Rare diseases",
                    "Healthcare access and equity",
                    "Traditional medicine practices",
                    "Global mental health initiatives",
                    "Cultural influences on health"
                ],
                "Environment": [
                    "Global warming",
                    "Endangered species",
                    "Climate change",
                    "Rainforests",
                    "Pollution",
                    "Biodiversity",
                    "Natural disasters",
                    "Sustainable development goals",
                    "Renewable energy sources",
                    "Marine conservation",
                    "Environmental activism",
                    "Urbanization impacts on the environment",
                    "Waste management solutions",
                    "Deforestation",
                    "Water scarcity",
                    "Environmental policies worldwide",
                    "Conservation biology",
                    "Air quality monitoring",
                    "Green technology innovations",
                    "Ecological footprints",
                    "Ozone layer depletion",
                    "Wildlife trafficking",
                    "Land degradation",
                    "Carbon footprint reduction",
                    "Ocean acidification",
                    "Environmental justice movements",
                    "Ecosystem restoration",
                    "Greenhouse gas emissions",
                    "Ecotourism",
                    "Arctic melting"
                ],
                "Technology": [
                    "Emerging technologies",
                    "AI advancements",
                    "Artificial intelligence",
                    "Machine learning",
                    "Space exploration",
                    "Cybersecurity threats",
                    "Blockchain technology",
                    "Quantum computing",
                    "Internet of Things (IoT)",
                    "Augmented reality",
                    "Virtual reality",
                    "5G technology",
                    "Biotechnology",
                    "Robotics",
                    "Ethical implications of technology",
                    "Big data analytics",
                    "Autonomous vehicles",
                    "Smart cities",
                    "Digital privacy concerns",
                    "Technology in healthcare",
                    "Human-computer interaction",
                    "Tech startups and innovation hubs",
                    "Smart home devices",
                    "Tech in education",
                    "Nanotechnology",
                    "3D printing advancements",
                    "Future of work technologies",
                    "Telemedicine",
                    "Tech and environmental sustainability",
                    "Space tourism"
                ],
                "Economy": [
                    "Wall Street Crash of 1929",
                    "Stock market performance",
                    "Job Markets",
                    "2007–2008 financial crisis",
                    "Unemployment rates",
                    "Global trade agreements",
                    "Cryptocurrencies",
                    "Economic recession",
                    "Inflation and deflation",
                    "Global economic outlook",
                    "Consumer behavior trends",
                    "Monetary policies",
                    "Economic inequality",
                    "Fiscal policies",
                    "Labor market disruptions",
                    "Sustainable business practices",
                    "Debt crisis",
                    "Central banks and their roles",
                    "Corporate governance",
                    "Economic globalization",
                    "Entrepreneurship trends",
                    "Economic development strategies",
                    "Financial technology (FinTech)",
                    "Government stimulus packages",
                    "International monetary systems",
                    "Supply chain disruptions",
                    "Economic recovery plans",
                    "Microfinance initiatives",
                    "Economic forecasting",
                    "Economic sanctions"
                ],
                "Entertainment": [
                    "Music Industry",
                    "Popular cultural events",
                    "Hollywood movies",
                    "Music festivals",
                    "Video streaming platforms",
                    "Celebrities",
                    "Award shows",
                    "Television series",
                    "Gaming industry",
                    "Animation movies",
                    "Documentary filmmaking",
                    "Online content creation",
                    "Fan culture",
                    "Theatre productions",
                    "Entertainment marketing strategies",
                    "Cinematography techniques",
                    "Streaming wars",
                    "Film distribution methods",
                    "Reality TV trends",
                    "Music genres evolution",
                    "Influence of social media on entertainment",
                    "Film festivals",
                    "Art and entertainment collaborations",
                    "Entertainment law",
                    "Entertainment journalism",
                    "Live event experiences",
                    "Entertainment merchandising",
                    "Celebrity endorsements",
                    "Streaming platform algorithms"
                ],
                "Sports": [
                    "Badminton",
                    "Basketball",
                    "Motorsport",
                    "Football",
                    "Cricket",
                    "Olympic records",
                    "Baseball",
                    "Golf",
                    "Tennis",
                    "Athletics",
                    "Boxing",
                    "Rugby",
                    "Swimming",
                    "Wrestling",
                    "Equestrian sports",
                    "Martial arts",
                    "Winter sports",
                    "Extreme sports",
                    "Paralympic sports",
                    "Sports psychology",
                    "Sports medicine advancements",
                    "Youth sports development",
                    "Esports",
                    "Sports broadcasting",
                    "Athlete endorsements",
                    "Sports analytics",
                    "Sports sponsorships",
                    "Team management strategies",
                    "Sports facilities and infrastructure"
                ],
                "Politics": [
                    "Presidential elections",
                    "Foreign policy",
                    "Democracy vs. Authoritarianism",
                    "Political parties",
                    "Human rights issues",
                    "Geopolitical conflicts",
                    "Election interference",
                    "Political ideologies",
                    "Political campaign strategies",
                    "International relations",
                    "Political polarization",
                    "Government corruption",
                    "Civil liberties",
                    "Nationalism movements",
                    "Policy-making processes",
                    "Political activism",
                    "Civic engagement",
                    "Lobbying and interest groups",
                    "Voting systems",
                    "State sovereignty",
                    "Media's role in politics",
                    "Peacekeeping missions",
                    "War crimes",
                    "Political propaganda",
                    "Diplomatic negotiations",
                    "Political accountability",
                    "Youth involvement in politics",
                    "Freedom of speech debates",
                    "Political asylum policies",
                    "Political leadership styles"
                ],
              "Education": [
                    "Online learning platforms",
                    "STEM education",
                    "School funding",
                    "Educational reforms",
                    "Digital classrooms",
                    "Higher education trends",
                    "Education technology",
                    "Special education programs",
                    "Education policy analysis",
                    "Global learning disparities",
                    "Early childhood education",
                    "Education for sustainable development",
                    "Education equity initiatives",
                    "Teacher training programs",
                    "Innovative teaching methodologies",
                    "Education assessment methods",
                    "Adult education programs",
                    "Vocational training",
                    "Education for global citizenship",
                    "Learning analytics",
                    "Language learning technologies",
                    "Education and social mobility",
                    "Education and employment linkage",
                    "Education curriculum design",
                    "Education and mental health",
                    "Education data privacy",
                    "Educational leadership",
                    "Parental involvement in education",
                    "Education in marginalized communities",
                    "Lifelong learning initiatives"
                ],
                "Travel": [
                    "Tourism hotspots",
                    "Airline industry challenges",
                    "Adventure travel destinations",
                    "Hotel chains",
                    "Travel tips",
                    "Sustainable travel practices",
                    "Cultural immersion experiences",
                    "Solo travel adventures",
                    "Budget travel hacks",
                    "Ecotourism destinations",
                    "Travel technology innovations",
                    "Luxury travel trends",
                    "Backpacking trails",
                    "Responsible tourism initiatives",
                    "Volunteer travel opportunities",
                    "Family-friendly travel destinations",
                    "Heritage tourism sites",
                    "Off-the-beaten-path explorations",
                    "Food tourism experiences",
                    "Wellness retreats",
                    "Digital nomad lifestyle",
                    "Travel insurance insights",
                    "Airport innovations",
                    "Transportation advancements",
                    "Art and travel collaborations",
                    "Cruise industry trends",
                    "Local travel experiences",
                    "Tourist behavior analysis",
                    "Accessible travel options",
                    "Travel during global crises"
                ],
                "Food": [
                    "Food Power",
                    "Famine",
                    "Food Security",
                    "Healthy eating",
                    "Farm-to-table movement",
                    "Fast food industry",
                    "Global food distribution",
                    "Veganism",
                    "Organic food trends",
                    "Culinary tourism",
                    "Food cultures around the world",
                    "Slow food movement",
                    "Street food culture",
                    "Gastronomy and society",
                    "Food and identity",
                    "Food sovereignty",
                    "Sustainable agriculture",
                    "Food labeling and regulations",
                    "Food scarcity solutions",
                    "Functional foods",
                    "Food technology innovations",
                    "Food waste management",
                    "GMO debates",
                    "Urban farming initiatives",
                    "Food education programs",
                    "Traditional cuisines preservation",
                    "Food and health policies",
                    "Future of food production",
                    "Food and climate change",
                    "Food industry labor issues"
                ]
            }

# %%
# Function to perform an initial search using MediaWiki API
def search_wikipedia(query, num_results=10):
    base_url = "https://en.wikipedia.org/w/api.php"
    params = {
        "action": "query",
        "list": "search",
        "srsearch": query,
        "format": "json",
        "srprop": "",
        "srlimit": num_results
    }

    response = requests.get(base_url, params=params)
    data = response.json()

    try: 
        search_results = data["query"]["search"]
    except e:
        print(f"Error: Unable to retrieve search results for query: {query}")
        print(f"Error: {e}")
        return []
    
    return search_results

# %%
def get_revision_id(page_title):
    base_url = "https://en.wikipedia.org/w/api.php"
    params = {
        "action": "query",
        "titles": page_title,
        "prop": "revisions",
        "rvprop": "ids",
        "format": "json"
    }

    response = requests.get(base_url, params=params)
    data = response.json()
    
    # Extract revision ID from the API response
    page_id = next(iter(data["query"]["pages"]))
    revision_id = data["query"]["pages"][page_id]["revisions"][0]["revid"]
    
    return revision_id

# %%
headers = {
        "User-Agent": "wiki_scraper/2.2 (Contact: aggarwalvatsal@gmail.com) - web scraping for IR research"
    }

# %% [markdown]
# ## Saving the obtained documents into a JSON file

# %%
# Save the topic_documents dictionary to a JSON file
def save_json_file(title, topic_documents):
    filename = title + ".json"
    with open(filename, 'w') as json_file:
        json.dump(topic_documents, json_file)

    print(f"Scraped documents saved to: {filename}")

# %%
def fetch_documents(topic, keywords, num_documents=5000, min_summary_length=200):
    documents = []
    unique_titles = set()
    wiki_wiki = wikipediaapi.Wikipedia("en", headers=headers)

    start_t = time.time()
    st_point = 0
    retry_attempts = 3  # Number of times to retry on timeout or error
    timeout_multiplier = 2  # Multiplier to increase timeout on each retry

    while len(documents) < num_documents:
        for i in range(st_point, len(keywords)):
            num_results = int((num_documents) / len(keywords)) + 1
            
            # Retry mechanism for fetching search results
            search_results = None
            retry_count = 0
            while retry_count < retry_attempts and not search_results:
                try:
                    search_results = search_wikipedia(keywords[i], num_results)
                except (wikipediaapi.exceptions.HTTPTimeoutError, wikipediaapi.exceptions.PageError):
                    retry_count += 1
                    print("Timeout (main): {} secs", 2 * retry_count)
                    time.sleep(2 * retry_count)  # Exponential backoff for retries

            if not search_results and st_point < len(keywords):
                continue
            elif not search_results and st_point >= len(keywords):
                break
            else:
                print(f"Querying documents for {topic} with {keywords[i]}....")

            for result in search_results:
                if len(unique_titles) >= num_documents:
                    break

                retry_count = 0
                while retry_count < retry_attempts:
                    try:
                        #timeout = random.uniform(0, 2)
                        #time.sleep(timeout)
                        page = wiki_wiki.page(result["title"])
                        break
                    except (wikipediaapi.exceptions.HTTPTimeoutError, wikipediaapi.exceptions.PageError):
                        retry_count += 1
                        print("Timeout (sub): {} secs", 2 * retry_count)
                        time.sleep(2 * retry_count)

                if retry_count == retry_attempts:
                    continue  # Skip to the next page in case of retries exhausted

                if len(page.summary) > min_summary_length and page.title not in unique_titles:
                    document_info = {
                        "revision_id": get_revision_id(page.title),
                        "title": page.title,
                        "summary": page.summary,
                        "url": page.fullurl,
                        "topic": topic
                    }
                    documents.append(document_info)
                    unique_titles.add(page.title)

            if len(documents) % 200 == 0:
                print(f"{len(documents)} scraped from Wikipedia in time {(time.time() - start_t):.2f} secs")
                
            if not os.path.exists("./notebook_jsons/" + topic):
                os.makedirs("./notebook_jsons/" + topic)
            save_json_file("./notebook_jsons/" + topic + "/" + keywords[i], documents)

        if len(documents) < num_documents:
            st_point = len(keywords)
            random.seed(1729)
            for link_name in random.sample(page.links.keys(), 5):
                if link_name not in keywords:
                    keywords.append(link_name)

    return documents

# %%
# Create a dictionary to store documents for each topic
topic_documents = {}

start_time = time.time()

# Create a dictionary to store documents for each topic
topic_documents = {}

random.seed(1729)

start_time = time.time()
i = 0
# Fetch documents for each topic
for topic, keywords in topic_dict3.items():
    if i >= 1: 
        documents = fetch_documents(topic, keywords)
        topic_documents[topic] = documents
        save_json_file("./notebook_jsons/" + topic, topic_documents)
    i += 1

print(f"Time taken to scrape all documents: {(time.time() - start_time):.2f} secs")
# Out:
# Querying documents for Environment with Global warming....
# Scraped documents saved to: ./notebook_jsons/Environment/Global warming.json
# Querying documents for Environment with Endangered species....
# Scraped documents saved to: ./notebook_jsons/Environment/Endangered species.json
# Querying documents for Environment with Climate change....
# Scraped documents saved to: ./notebook_jsons/Environment/Climate change.json
# Querying documents for Environment with Rainforests....
# Scraped documents saved to: ./notebook_jsons/Environment/Rainforests.json
# Querying documents for Environment with Pollution....
# Scraped documents saved to: ./notebook_jsons/Environment/Pollution.json
# Querying documents for Environment with Biodiversity....
# Scraped documents saved to: ./notebook_jsons/Environment/Biodiversity.json
# Querying documents for Environment with Natural disasters....
# Scraped documents saved to: ./notebook_jsons/Environment/Natural disasters.json
# Querying documents for Environment with Sustainable development goals....
# Scraped documents saved to: ./notebook_jsons/Environment/Sustainable development goals.json
# Querying documents for Environment with Renewable energy sources....
# Scraped documents saved to: ./notebook_jsons/Environment/Renewable energy sources.json
# Querying documents for Environment with Marine conservation....
# Scraped documents saved to: ./notebook_jsons/Environment/Marine conservation.json
# Querying documents for Environment with Environmental activism....
# Scraped documents saved to: ./notebook_jsons/Environment/Environmental activism.json
# Querying documents for Environment with Urbanization impacts on the environment....
# Scraped documents saved to: ./notebook_jsons/Environment/Urbanization impacts on the environment.json
# Querying documents for Environment with Waste management solutions....
# Scraped documents saved to: ./notebook_jsons/Environment/Waste management solutions.json
# Querying documents for Environment with Deforestation....
# Scraped documents saved to: ./notebook_jsons/Environment/Deforestation.json
# Querying documents for Environment with Water scarcity....
# Scraped documents saved to: ./notebook_jsons/Environment/Water scarcity.json
# Querying documents for Environment with Environmental policies worldwide....
# Scraped documents saved to: ./notebook_jsons/Environment/Environmental policies worldwide.json
# Querying documents for Environment with Conservation biology....
# Scraped documents saved to: ./notebook_jsons/Environment/Conservation biology.json
# Querying documents for Environment with Air quality monitoring....
# Scraped documents saved to: ./notebook_jsons/Environment/Air quality monitoring.json
# Querying documents for Environment with Green technology innovations....
# Scraped documents saved to: ./notebook_jsons/Environment/Green technology innovations.json
# Querying documents for Environment with Ecological footprints....
# Scraped documents saved to: ./notebook_jsons/Environment/Ecological footprints.json
# Querying documents for Environment with Ozone layer depletion....
# Scraped documents saved to: ./notebook_jsons/Environment/Ozone layer depletion.json
# Querying documents for Environment with Wildlife trafficking....
# Scraped documents saved to: ./notebook_jsons/Environment/Wildlife trafficking.json
# Querying documents for Environment with Land degradation....
# Scraped documents saved to: ./notebook_jsons/Environment/Land degradation.json
# Querying documents for Environment with Carbon footprint reduction....
# Scraped documents saved to: ./notebook_jsons/Environment/Carbon footprint reduction.json
# Querying documents for Environment with Ocean acidification....
# Scraped documents saved to: ./notebook_jsons/Environment/Ocean acidification.json
# Querying documents for Environment with Environmental justice movements....
# Scraped documents saved to: ./notebook_jsons/Environment/Environmental justice movements.json
# Querying documents for Environment with Ecosystem restoration....
# Scraped documents saved to: ./notebook_jsons/Environment/Ecosystem restoration.json
# Querying documents for Environment with Greenhouse gas emissions....
# Scraped documents saved to: ./notebook_jsons/Environment/Greenhouse gas emissions.json
# Querying documents for Environment with Ecotourism....
# Scraped documents saved to: ./notebook_jsons/Environment/Ecotourism.json
# Querying documents for Environment with Arctic melting....
# Scraped documents saved to: ./notebook_jsons/Environment/Arctic melting.json
# C:\Users\vatsa\AppData\Local\Temp\ipykernel_49732\205884671.py:73: DeprecationWarning: Sampling from a set deprecated
# since Python 3.9 and will be removed in a subsequent version.
#   for link_name in random.sample(page.links.keys(), 5):
# Querying documents for Environment with Losing Earth....
# Scraped documents saved to: ./notebook_jsons/Environment/Losing Earth.json
# Querying documents for Environment with Template:Cite web....
# Scraped documents saved to: ./notebook_jsons/Environment/Template:Cite web.json
# Querying documents for Environment with Bill Clinton....
# Scraped documents saved to: ./notebook_jsons/Environment/Bill Clinton.json
# Querying documents for Environment with International Coral Reef Initiative....
# Scraped documents saved to: ./notebook_jsons/Environment/International Coral Reef Initiative.json
# Querying documents for Environment with John Chafee....
# Scraped documents saved to: ./notebook_jsons/Environment/John Chafee.json
# Querying documents for Environment with 1867 in the United States....
# Scraped documents saved to: ./notebook_jsons/Environment/1867 in the United States.json
# Querying documents for Environment with List of Phillips Academy Heads of School....
# Scraped documents saved to: ./notebook_jsons/Environment/List of Phillips Academy Heads of School.json
# Querying documents for Environment with Richard O. Ristine....
# Scraped documents saved to: ./notebook_jsons/Environment/Richard O. Ristine.json
# Querying documents for Environment with Michael Waltrip....
# Scraped documents saved to: ./notebook_jsons/Environment/Michael Waltrip.json
# Querying documents for Environment with 2015 in the United States....
# Scraped documents saved to: ./notebook_jsons/Environment/2015 in the United States.json
# Querying documents for Environment with Wind power in Alaska....
# 5000 scraped from Wikipedia in time 2829.11 secs
# Scraped documents saved to: ./notebook_jsons/Environment/Wind power in Alaska.json
# Querying documents for Environment with Calvin Coolidge....
# 5000 scraped from Wikipedia in time 2829.77 secs
# Scraped documents saved to: ./notebook_jsons/Environment/Calvin Coolidge.json
# Querying documents for Environment with Petroleum in Pakistan....
# 5000 scraped from Wikipedia in time 2830.40 secs
# Scraped documents saved to: ./notebook_jsons/Environment/Petroleum in Pakistan.json
# Querying documents for Environment with Plains All American Pipeline....
# 5000 scraped from Wikipedia in time 2831.10 secs
# Scraped documents saved to: ./notebook_jsons/Environment/Plains All American Pipeline.json
# Querying documents for Environment with Petroleum in Thailand....
# 5000 scraped from Wikipedia in time 2831.74 secs
# Scraped documents saved to: ./notebook_jsons/Environment/Petroleum in Thailand.json
# Scraped documents saved to: ./notebook_jsons/Environment.json
# Querying documents for Technology with Emerging technologies....
# Scraped documents saved to: ./notebook_jsons/Technology/Emerging technologies.json
# Querying documents for Technology with AI advancements....
# Scraped documents saved to: ./notebook_jsons/Technology/AI advancements.json
# Querying documents for Technology with Artificial intelligence....
# Scraped documents saved to: ./notebook_jsons/Technology/Artificial intelligence.json
# Querying documents for Technology with Machine learning....
# Scraped documents saved to: ./notebook_jsons/Technology/Machine learning.json
# Querying documents for Technology with Space exploration....
# Scraped documents saved to: ./notebook_jsons/Technology/Space exploration.json
# Querying documents for Technology with Cybersecurity threats....
# Scraped documents saved to: ./notebook_jsons/Technology/Cybersecurity threats.json
# Querying documents for Technology with Blockchain technology....
# Scraped documents saved to: ./notebook_jsons/Technology/Blockchain technology.json
# Querying documents for Technology with Quantum computing....
# Scraped documents saved to: ./notebook_jsons/Technology/Quantum computing.json
# Querying documents for Technology with Internet of Things (IoT)....
# Scraped documents saved to: ./notebook_jsons/Technology/Internet of Things (IoT).json
# Querying documents for Technology with Augmented reality....
# Scraped documents saved to: ./notebook_jsons/Technology/Augmented reality.json
# Querying documents for Technology with Virtual reality....
# Scraped documents saved to: ./notebook_jsons/Technology/Virtual reality.json
# Querying documents for Technology with 5G technology....
# Scraped documents saved to: ./notebook_jsons/Technology/5G technology.json
# Querying documents for Technology with Biotechnology....
# Scraped documents saved to: ./notebook_jsons/Technology/Biotechnology.json
# Querying documents for Technology with Robotics....
# Scraped documents saved to: ./notebook_jsons/Technology/Robotics.json
# Querying documents for Technology with Ethical implications of technology....
# Scraped documents saved to: ./notebook_jsons/Technology/Ethical implications of technology.json
# Querying documents for Technology with Big data analytics....
# Scraped documents saved to: ./notebook_jsons/Technology/Big data analytics.json
# Querying documents for Technology with Autonomous vehicles....
# Scraped documents saved to: ./notebook_jsons/Technology/Autonomous vehicles.json
# Querying documents for Technology with Smart cities....
# Scraped documents saved to: ./notebook_jsons/Technology/Smart cities.json
# Querying documents for Technology with Digital privacy concerns....
# Scraped documents saved to: ./notebook_jsons/Technology/Digital privacy concerns.json
# Querying documents for Technology with Technology in healthcare....
# Scraped documents saved to: ./notebook_jsons/Technology/Technology in healthcare.json
# Querying documents for Technology with Human-computer interaction....
# Scraped documents saved to: ./notebook_jsons/Technology/Human-computer interaction.json
# Querying documents for Technology with Tech startups and innovation hubs....
# Scraped documents saved to: ./notebook_jsons/Technology/Tech startups and innovation hubs.json
# Querying documents for Technology with Smart home devices....
# Scraped documents saved to: ./notebook_jsons/Technology/Smart home devices.json
# Querying documents for Technology with Tech in education....
# Scraped documents saved to: ./notebook_jsons/Technology/Tech in education.json
# Querying documents for Technology with Nanotechnology....
# Scraped documents saved to: ./notebook_jsons/Technology/Nanotechnology.json
# Querying documents for Technology with 3D printing advancements....
# Scraped documents saved to: ./notebook_jsons/Technology/3D printing advancements.json
# Querying documents for Technology with Future of work technologies....
# Scraped documents saved to: ./notebook_jsons/Technology/Future of work technologies.json
# Querying documents for Technology with Telemedicine....
# Scraped documents saved to: ./notebook_jsons/Technology/Telemedicine.json
# Querying documents for Technology with Tech and environmental sustainability....
# Scraped documents saved to: ./notebook_jsons/Technology/Tech and environmental sustainability.json
# Querying documents for Technology with Space tourism....
# Scraped documents saved to: ./notebook_jsons/Technology/Space tourism.json
# Querying documents for Technology with Space colonization....
# Scraped documents saved to: ./notebook_jsons/Technology/Space colonization.json
# Querying documents for Technology with Anousheh Ansari....
# Scraped documents saved to: ./notebook_jsons/Technology/Anousheh Ansari.json
# Querying documents for Technology with New Glenn....
# Scraped documents saved to: ./notebook_jsons/Technology/New Glenn.json
# Querying documents for Technology with Redwire....
# Scraped documents saved to: ./notebook_jsons/Technology/Redwire.json
# Querying documents for Technology with Orion Span....
# Scraped documents saved to: ./notebook_jsons/Technology/Orion Span.json
# Querying documents for Technology with Andrei Iosivas....
# Scraped documents saved to: ./notebook_jsons/Technology/Andrei Iosivas.json
# Querying documents for Technology with Template:Carolina Panthers roster navbox....
# Scraped documents saved to: ./notebook_jsons/Technology/Template:Carolina Panthers roster navbox.json
# Querying documents for Technology with Template:San Francisco 49ers roster navbox....
# Scraped documents saved to: ./notebook_jsons/Technology/Template:San Francisco 49ers roster navbox.json
# Querying documents for Technology with Template:Las Vegas Raiders roster navbox....
# Scraped documents saved to: ./notebook_jsons/Technology/Template:Las Vegas Raiders roster navbox.json
# Querying documents for Technology with IMG Academy....
# Scraped documents saved to: ./notebook_jsons/Technology/IMG Academy.json
# Querying documents for Technology with Serbian Cyrillic alphabet....
# Scraped documents saved to: ./notebook_jsons/Technology/Serbian Cyrillic alphabet.json
# Querying documents for Technology with 2018 Shenzhen Longhua Open – Men's singles....
# 5000 scraped from Wikipedia in time 2771.21 secs
# Scraped documents saved to: ./notebook_jsons/Technology/2018 Shenzhen Longhua Open – Men's singles.json
# Querying documents for Technology with Ernests Gulbis....
# 5000 scraped from Wikipedia in time 2771.79 secs
# Scraped documents saved to: ./notebook_jsons/Technology/Ernests Gulbis.json
# Querying documents for Technology with Karen Khachanov....
# 5000 scraped from Wikipedia in time 2772.48 secs
# Scraped documents saved to: ./notebook_jsons/Technology/Karen Khachanov.json
# Querying documents for Technology with Hubert Hurkacz....
# 5000 scraped from Wikipedia in time 2773.16 secs
# Scraped documents saved to: ./notebook_jsons/Technology/Hubert Hurkacz.json
# Scraped documents saved to: ./notebook_jsons/Technology.json
# Querying documents for Economy with Wall Street Crash of 1929....
# Scraped documents saved to: ./notebook_jsons/Economy/Wall Street Crash of 1929.json
# Querying documents for Economy with Stock market performance....
# Scraped documents saved to: ./notebook_jsons/Economy/Stock market performance.json
# Querying documents for Economy with Job Markets....
# Scraped documents saved to: ./notebook_jsons/Economy/Job Markets.json
# Querying documents for Economy with 2007–2008 financial crisis....
# Scraped documents saved to: ./notebook_jsons/Economy/2007–2008 financial crisis.json
# Querying documents for Economy with Unemployment rates....
# Scraped documents saved to: ./notebook_jsons/Economy/Unemployment rates.json
# Querying documents for Economy with Global trade agreements....
# Scraped documents saved to: ./notebook_jsons/Economy/Global trade agreements.json
# Querying documents for Economy with Cryptocurrencies....
# Scraped documents saved to: ./notebook_jsons/Economy/Cryptocurrencies.json
# Querying documents for Economy with Economic recession....
# Scraped documents saved to: ./notebook_jsons/Economy/Economic recession.json
# Querying documents for Economy with Inflation and deflation....
# Scraped documents saved to: ./notebook_jsons/Economy/Inflation and deflation.json
# Querying documents for Economy with Global economic outlook....
# Scraped documents saved to: ./notebook_jsons/Economy/Global economic outlook.json
# Querying documents for Economy with Consumer behavior trends....

# %%
def is_alphanumeric(text):
    # Remove any whitespace from the text
    cleaned_text = text.replace(" ", "")
    
    # Check if the cleaned text is alphanumeric
    return cleaned_text.isalnum()

# %%
def preprocess_text(text):
    # Define a regular expression pattern to match non-alphanumeric characters
    # The pattern [^\w\s] matches any character that is not a word character (alphanumeric) or whitespace
    pattern = r'[^\w]'
    
    
    # Use the re.sub() function to replace matched characters with an empty string
    cleaned_text = re.sub(pattern, ' ', text)
    
    return cleaned_text

# %% [markdown]
# ### Checking count of alphanumeric document

# %%
# Iterate through the list of dictionaries and check each summary
alphanumeric_doc_count = 0
count = 0
for key in topic_documents.keys():
    for document_info in topic_documents[key]:
        #print(document_info)
        document_info["summary"] = preprocess_text(document_info["summary"])
        #print(summary)
        
        if is_alphanumeric(document_info["summary"]):
            alphanumeric_doc_count += 1
        else:
            count += 1
            if count % 10 == 0:
                print("******* BREAKING PREMPTIVELY ********")

# Print the count of alphanumeric summaries
print(f"Number, Percentage of alphanumeric summaries: {alphanumeric_doc_count, (alphanumeric_doc_count/6000)*100}")

# %%
topic_documents

# %% [markdown]
# ### Saving the JSON after preprocessing and replacing non-alphanumeric with whitespace using regex

# %%
filename = "wiki_documents_scraped_preprocessed.json"

with open(filename, 'w') as json_file:
    json.dump(topic_documents, json_file)

print(f"Scraped documents saved to: {filename}")
